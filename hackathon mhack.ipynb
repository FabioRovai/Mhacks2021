# %%
# !pip install pdfplumber --quiet
# !pip install earthy
# !pip install git+https://github.com/ramsrigouthamg/Questgen.ai
# !pip install sense2vec==1.0.2
# !pip install git+https://github.com/boudinfl/pke.git
# !python -m nltk.downloader universal_tagset
# !python -m spacy download en
# !wget https://github.com/explosion/sense2vec/releases/download/v1.0.0/s2v_reddit_2015_md.tar.gz
# !tar -xvf  s2v_reddit_2015_md.tar.gz
# !ls s2v_old
# Out:
#      |████████████████████████████████| 45 kB 1.4 MB/s
#      |████████████████████████████████| 5.6 MB 9.7 MB/s
#      |████████████████████████████████| 139 kB 43.7 MB/s
#      |████████████████████████████████| 1.9 MB 19.1 MB/s
# ...
#      |████████████████████████████████| 46 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 157 kB 8.7 MB/s
# ...
#   Created wheel for earthy: filename=earthy-0.0.12-py3-none-any.whl size=46975 sha256=fd14379c750a02f3861212f521384576d89ab421fc951f5db5f32528658954d6
#   Stored in directory: /root/.cache/pip/wheels/e8/57/c3/c7aca92949eedb50f3e5c97bae137920c69057ecb5318295bd
# ...
#   Created wheel for charguana: filename=charguana-0.1.15-py3-none-any.whl size=187890 sha256=82a1897652c825cd878da3c5340f7fdc68f70ba1cb15f38b46cffe0b2b4aabf3
#   Stored in directory: /root/.cache/pip/wheels/31/4b/79/803d79c08c25911181fdfa969fc61d06375dfba663a839bfa6
# Successfully built earthy charguana
# ...

# %%
import pdfplumber
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
import gensim
from gensim.summarization import summarize
from nltk.stem import WordNetLemmatizer 
import re
from pprint import pprint
nltk.download('stopwords')
from Questgen import main
from transformers import GPT2Tokenizer,GPT2LMHeadModel
from gensim.parsing.preprocessing import remove_stopwords
from collections import Counter
#https://stackabuse.com/removing-stop-words-from-strings-in-python/
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
pdf = pdfplumber.open('/content/f.pdf')
page = pdf.pages[0] #select page
lines = page.extract_text() #download
foo=lines #make copy
lines=re.sub('[^A-Za-z]+', ' ', lines) #strip
lemmatizer = WordNetLemmatizer()
word_list = nltk.word_tokenize(lines)
lines = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
word_list = nltk.word_tokenize(lines)
lines=lines.lower()
lines = remove_stopwords(lines)
lines=lines.split('\n')
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1 

lines=listToString(lines)
from earthy.nltk_wrappers import lemmatize_sent
lines, lemmas, tags = zip(*lemmatize_sent(lines))
#lines=lines.split(' ')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
lemmas = [i for i in lemmas if len(i) > 1]

# %%
x=Counter(lemmas)
x.most_common(5)

#words, lemmas, tags = zip(*lemmatize_sent(lines))
# Out:
# [('cell', 23), ('organism', 6), ('life', 5), ('single', 3), ('diversity', 3)]

# %%
words = str(foo).split('\n')
words
matches = [match for match in words if 'cell' in match]     
# Driver code    
miao=listToString(matches)
#len(matches)

# %%
matches
# Out:
# ['A single ~200 micrometer (!m) cell,the human egg,with',
#  'sperm,which are also single cells.From the union of an egg',
#  'and sperm will arise the 10 trillion cells of a human body.',
#  'Like ourselves, the individual cells that form our bodies 1.1 The Diversity and Commonality ',
#  'actions. These abilities define life. We and other multicellular',
#  'organisms contain billions or trillions of cells organized into',
#  'cell. Even simple unicellular organisms exhibit all the hall-',
#  'mark properties of life, indicating that the cell is the funda-',
#  'cells but is an absolute requirement for others. Most cells in',
#  'multicellular organisms are intimately involved with other',
#  'an explosion of new data about the components of cells,',
#  'cells. Although some unicellular organisms live in isolation,',
#  'particularly about how information flows through cells and',
#  'Molecular cell biology is a rich, integrative science that',
# ...

# %%
miao
# Out:
# 'A single ~200 micrometer (!m) cell,the human egg,withsperm,which are also single cells.From the union of an eggand sperm will arise the 10 trillion cells of a human body.Like ourselves, the individual cells that form our bodies 1.1 The Diversity and Commonality actions. These abilities define life. We and other multicellularorganisms contain billions or trillions of cells organized intocell. Even simple unicellular organisms exhibit all the hall-mark properties of life, indicating that the cell is the funda-cells but is an absolute requirement for others. Most cells inmulticellular organisms are intimately involved with otheran explosion of new data about the components of cells,cells. Although some unicellular organisms live in isolation,particularly about how information flows through cells andMolecular cell biology is a rich, integrative science thatthe multifaceted story of the birth, life, and death of cells. We 1.3  The Work of Cellscells, their basic constituents and critical
# ...

# %%
# Passing the text corpus to summarizer
summary_by_word_count=summarize(miao)
summary_by_word_count
# Out:
# 'Although some unicellular organisms live in isolation,particularly about how information flows through cells andMolecular cell biology is a rich, integrative science thatthe multifaceted story of the birth, life, and death of cells.'

# %%
'''import gensim
from gensim.summarization import summarize

# Passing the text corpus to summarizer
summary_by_word_count=summarize(miao,word_count=30)
print(summary_by_word_count)'''

# !pip install transformers --q

# %%
#https://www.machinelearningplus.com/nlp/text-summarization-approaches-nlp-example/

# Importing requirements
from transformers import T5Tokenizer, T5Config, T5ForConditionalGeneration

# %%
# !pip install sentencepiece --q

# %%
my_model = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')
# Out:
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-95db19cd822c> in <module>()
# ----> 1 my_model = T5ForConditionalGeneration.from_pretrained('t5-small')
#       2 tokenizer = T5Tokenizer.from_pretrained('t5-small')
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     650                     proxies=proxies,
#     651                     resume_download=resume_download,
# --> 652                     local_files_only=local_files_only,
#     653                 )
#     654                 if resolved_archive_file is None:
#
# ...

# %%
text = "summarize:" + miao
text

# %%
#question generation
#https://towardsdatascience.com/questgen-an-open-source-nlp-library-for-question-generation-algorithms-1e18067fcdc6

nltk.download('stopwords')

qe= main.BoolQGen()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
payload = {
            "input_text": summary_by_word_count }
output = qe.predict_boolq(payload)
pprint (output)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# {'Boolean Questions': ['Is cell biology the same as cellular biology?',
#                        'Is cell biology and cellular biology the same?',
#                        'Is cell biology and cellular biology the same thing?'],
#  'Count': 4,
#  'Text': 'Although some unicellular organisms live in isolation,particularly '
#          'about how information flows through cells andMolecular cell biology '
# ...

# %%
##EXTRA

# %%
###topic modeller
##https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21



import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
import pandas as pd
df = pd.DataFrame([x.split(';') for x in summary_by_word_count.split('.')])
df.to_csv('miao.csv')
df
# Out:
#                                                    0
# 0  Although some unicellular organisms live in is...
# 1

# %%
text_data = []
with open('miao.csv') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        text_data.append(tokens)

# %%
text_data
# Out:
# [[],
#  ['0,"although',
#   'unicellular',
#   'organism',
#   'isolation',
#   'particularly',
#   'information',
#   'flow',
#   'cell',
#   'andmolecular',
#   'biology',
#   'integrative',
#   'science',
#   'thatthe',
#   'multifaceted',
#   'story',
#   'birth',
#   'death',
#   'cell'],
#  []]

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 1
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')

# %%
topics = ldamodel.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.086*"cell" + 0.057*"story" + 0.057*"particularly" + 0.057*"science" + 0.057*"multifaceted"')

# %%
###TEST###
bar='In vertebrates, the p53 response evolved to induce apoptosis in the face of extensive DNA damage, presumably to prevent the accumulation of multiple mutations that might convert a normal cell into a cancer cell'
df = pd.DataFrame([x.split(';') for x in bar.split('\n')])
df.to_csv('bar.csv')
df
# Out:
#                                                    0
# 0  In vertebrates, the p53 response evolved to in...

# %%
text_data = []
with open('bar.csv') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        text_data.append(tokens)

dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 1
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')

# %%
topics = ldamodel.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.059*"normal" + 0.059*"prevent" + 0.059*"mutation" + 0.059*"might" + 0.059*"presumably"')

# %%
###### Chapter indexing####

# %%
# !pip install fitz --q
# Out:
#      |████████████████████████████████| 78 kB 3.6 MB/s
#      |████████████████████████████████| 3.2 MB 25.1 MB/s
#      |████████████████████████████████| 129 kB 71.0 MB/s
#      |████████████████████████████████| 5.1 MB 38.4 MB/s
#      |████████████████████████████████| 421 kB 52.2 MB/s
#      |████████████████████████████████| 407 kB 54.5 MB/s
#      |████████████████████████████████| 45 kB 3.4 MB/s
#      |████████████████████████████████| 6.3 MB 26.1 MB/s
# ...

# %%
# !pip install PyMuPDF --q
# Out:
#      |████████████████████████████████| 8.7 MB 1.1 MB/s

# %%
#This is from your link

# %%
from operator import itemgetter
import fitz
import json


def fonts(doc, granularity=False):
    """Extracts fonts and their usage in PDF documents.
    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param granularity: also use 'font', 'flags' and 'color' to discriminate text
    :type granularity: bool
    :rtype: [(font_size, count), (font_size, count}], dict
    :return: most used fonts sorted by count, font style information
    """
    styles = {}
    font_counts = {}

    for page in doc:
        blocks = page.getText("dict")["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # block contains text
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if granularity:
                            identifier = "{0}_{1}_{2}_{3}".format(s['size'], s['flags'], s['font'], s['color'])
                            styles[identifier] = {'size': s['size'], 'flags': s['flags'], 'font': s['font'],
                                                  'color': s['color']}
                        else:
                            identifier = "{0}".format(s['size'])
                            styles[identifier] = {'size': s['size'], 'font': s['font']}

                        font_counts[identifier] = font_counts.get(identifier, 0) + 1  # count the fonts usage

    font_counts = sorted(font_counts.items(), key=itemgetter(1), reverse=True)

    if len(font_counts) < 1:
        raise ValueError("Zero discriminating fonts found!")

    return font_counts, styles


def font_tags(font_counts, styles):
    """Returns dictionary with font sizes as keys and tags as value.
    :param font_counts: (font_size, count) for all fonts occuring in document
    :type font_counts: list
    :param styles: all styles found in the document
    :type styles: dict
    :rtype: dict
    :return: all element tags based on font-sizes
    """
    p_style = styles[font_counts[0][0]]  # get style for most used font by count (paragraph)
    p_size = p_style['size']  # get the paragraph's size

    # sorting the font sizes high to low, so that we can append the right integer to each tag
    font_sizes = []
    for (font_size, count) in font_counts:
        font_sizes.append(float(font_size))
    font_sizes.sort(reverse=True)

    # aggregating the tags for each font size
    idx = 0
    size_tag = {}
    for size in font_sizes:
        idx += 1
        if size == p_size:
            idx = 0
            size_tag[size] = '<p>'
        if size > p_size:
            size_tag[size] = '<h{0}>'.format(idx)
        elif size < p_size:
            size_tag[size] = '<s{0}>'.format(idx)

    return size_tag


def headers_para(doc, size_tag):
    """Scrapes headers & paragraphs from PDF and return texts with element tags.
    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param size_tag: textual element tags for each size
    :type size_tag: dict
    :rtype: list
    :return: texts with pre-prended element tags
    """
    header_para = []  # list with headers and paragraphs
    first = True  # boolean operator for first header
    previous_s = {}  # previous span

    for page in doc:
        blocks = page.getText("dict")["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # this block contains text

                # REMEMBER: multiple fonts and sizes are possible IN one block

                block_string = ""  # text found in block
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if s['text'].strip():  # removing whitespaces:
                            if first:
                                previous_s = s
                                first = False
                                block_string = size_tag[s['size']] + s['text']
                            else:
                                if s['size'] == previous_s['size']:

                                    if block_string and all((c == "|") for c in block_string):
                                        # block_string only contains pipes
                                        block_string = size_tag[s['size']] + s['text']
                                    if block_string == "":
                                        # new block has started, so append size tag
                                        block_string = size_tag[s['size']] + s['text']
                                    else:  # in the same block, so concatenate strings
                                        block_string += " " + s['text']

                                else:
                                    header_para.append(block_string)
                                    block_string = size_tag[s['size']] + s['text']

                                previous_s = s

                    # new block started, indicating with a pipe
                    block_string += "|"

                header_para.append(block_string)

    return header_para


def main():

    document = 'f.pdf'
    doc = fitz.open(document)

    font_counts, styles = fonts(doc, granularity=False)

    size_tag = font_tags(font_counts, styles)

    elements = headers_para(doc, size_tag)

    with open("doc.json", 'w') as json_out:
        json.dump(elements, json_out)


if __name__ == '__main__':
    main()
# Out:
# Deprecation: 'getText' removed from class 'Page' after v1.19.0 - use 'get_text'.

# %%
#Conversion of tokens in txt

import pandas as pd
df = pd.read_json('doc.json')
df#22
df.to_csv('x.txt', sep=',', index=False)

# %%
#Read back
f = open("x.txt", "r")
f=f.readlines()

# %%
#https://stackoverflow.com/questions/55893314/how-to-search-for-a-keyword-in-a-list-of-strings-and-return-that-string
#Find token font
l1 = [k for k in f if '<h22>CHA' in  k]

# %%
#Clean everything else
lista=set(l1)
index=list(lista)
import re
hpp=[re.sub(r'<h22>CHA P TE R  ', 'CHAPTER ', i)for i in index]
hpp=[re.sub(r'"', '', i)for i in hpp]
hbb=  [i.split("•", 1)[0] for i in hpp]

hbb
# Out:
# ['CHAPTER 22 ', 'CHAPTER 21 ']

# %%
#Download entire corpus (Takes a minute for 2 chapters)
import os
import pdfplumber

directory = r'/content/'

for filename in os.listdir(directory):
    if filename.endswith('.pdf'):
        fullpath = os.path.join(directory, filename)
        #print(fullpath)
        all_text = ""
        with pdfplumber.open(fullpath) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                #print(text)
                all_text += '\n' + text
        with open('all_text.txt', 'w') as f:
          f.write(all_text)

# %%
numberChapter=0 #choose chapter (this is 21 from my machine, because i am working with a reduced corpus (only chapter 21 and 22))

# %%
all_textstart=all_text[all_text.find(hbb[0]):]
ChapterIndex=all_textstart.split(hbb[0+1], 1)[0]

#ChapterIndex

all_textstart
# Out:
# 'CHAPTER 22 • Cell Birth, Lineage, And Death\n!FIGURE 22-1 Overview of the birth,lineage,and death\nof cells. Following growth, cells are “born” as the result of\nsymmetric or asymmetric cell division. (a) The two daughter cells\nCell growth\nresulting from symmetric division are essentially identical to each\nother and to the parental cell. Such daughter cells subsequently (a) (b)\ncan have different fates if they are exposed to different signals.\nSymmetric\nThe two daughter cells resulting from asymmetric division differ\ndivision Cell\nfrom birth and consequently have different fates. Asymmetric birth\ndivision commonly is preceded by the localization of regulatory\nmolecules (green) in one part of the parent cell. (b) A series of Cell growthFPO\nsymmetric and/or asymmetric cell divisions, called a cell lineage,\ngives birth to each of the specialized cell types found in a\nAsymmetric\nmulticellular organism. The pattern of cell lineage can be under Cell\ndivision \ndeath\ntight 
# ...

# %%
hbb[0]
# Out:
# '"CHAPTER 22 '

# %%
hbb[1]
# Out:
# 'CHAPTER 21 '

# %%
with open('ggggggg.txt', 'w') as f:
    f.write(all_text)

# %%
all_text
# Out:
# '\n1\nLIFE BEGINS \nWITH CELLS\nA single ~200 micrometer (!m) cell,the human egg,with\nsperm,which are also single cells.From the union of an egg\nand sperm will arise the 10 trillion cells of a human body.\n[Photo Researchers, Inc.]\nLike ourselves, the individual cells that form our bodies 1.1 The Diversity and Commonality \ncan grow, reproduce, process information, respond to\nof Cells\nstimuli, and carry out an amazing array of chemical re-\nactions. These abilities define life. We and other multicellular\nCells come in an amazing variety of sizes and shapes (Figure\norganisms contain billions or trillions of cells organized into\n1-1). Some move rapidly and have fast-changing structures, as\ncomplex structures, but many organisms consist of a single\nwe can see in movies of amoebae and rotifers. Others are\ncell. Even simple unicellular organisms exhibit all the hall-\nlargely stationary and structurally stable. Oxygen kills some\nmark properties of life, indicating that the cel
# ...

# %%
all_text
# Out:
# '\n1\nLIFE BEGINS \nWITH CELLS\nA single ~200 micrometer (!m) cell,the human egg,with\nsperm,which are also single cells.From the union of an egg\nand sperm will arise the 10 trillion cells of a human body.\n[Photo Researchers, Inc.]\nLike ourselves, the individual cells that form our bodies 1.1 The Diversity and Commonality \ncan grow, reproduce, process information, respond to\nof Cells\nstimuli, and carry out an amazing array of chemical re-\nactions. These abilities define life. We and other multicellular\nCells come in an amazing variety of sizes and shapes (Figure\norganisms contain billions or trillions of cells organized into\n1-1). Some move rapidly and have fast-changing structures, as\ncomplex structures, but many organisms consist of a single\nwe can see in movies of amoebae and rotifers. Others are\ncell. Even simple unicellular organisms exhibit all the hall-\nlargely stationary and structurally stable. Oxygen kills some\nmark properties of life, indicating that the cel
# ...
